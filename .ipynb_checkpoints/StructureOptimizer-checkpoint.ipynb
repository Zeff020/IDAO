# %%
import tensorflow as tf
import keras
from keras import backend as K
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import pandas as pd
import utils
import scoring
import numpy as np

from skopt import Optimizer

from skopt.learning import GaussianProcessRegressor
from skopt.learning.gaussian_process.kernels import Matern, RBF, WhiteKernel

from skopt.learning import RandomForestRegressor

from skopt.acquisition import gaussian_ei as acq_func

# %%
def relu(x):
  return np.array([ (i>0) * abs(i) for i in x ])

DATA_PATH = "./data/"

train, test = utils.load_small_data_csv(DATA_PATH,"train_smaller100.csv.gz" , "test_smaller100.csv.gz", utils.SIMPLE_FEATURE_COLUMNS)

# %%
#### Original keras network ####

PointResiduals,Angles = utils.kink(train)
train['PointResiduals'] = pd.Series(PointResiduals, index=train.index)
train['Angles'] = pd.Series(PointResiduals, index=train.index)


train_part, val_part = train_test_split(train, test_size=0.20, shuffle=True)
x_train = train_part.loc[:, utils.SIMPLE_FEATURE_COLUMNS].values
x_val   =  val_part.loc[:, utils.SIMPLE_FEATURE_COLUMNS].values
y_train = train_part.loc[:, ["label"]].values
y_val = val_part.loc[:, ["label"]].values
#y_train_weight = train_part.loc[:, ["weight"]].values

# turn labels into categorical classes
classes = [0,1]
y_train = keras.utils.to_categorical(y_train, num_classes=len(classes))
y_val   = keras.utils.to_categorical(y_val,   num_classes=len(classes))



## Model

INIT_LEARNINGRATE = 5e-3
BATCH_SIZE = 16  # should be a factor of len(x_train) and len(x_val) etc.
EPOCHS = 3

assert len(y_train) == len(x_train), "x_train and y_train not same length!"
#assert len(y_train) % BATCH_SIZE == 0, "batch size should be multiple of training size,{0}/{1}".format(len(y_train),BATCH_SIZE)

from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.layers.normalization import BatchNormalization

K.clear_session()

model = Sequential()
model.add(Dense(100, activation='relu', input_shape=( len( utils.SIMPLE_FEATURE_COLUMNS ), ))) #length = input vars
model.add(BatchNormalization())
model.add(Dropout(0.1))
model.add(Dense(50 , activation='relu'))
model.add(Dense( len(classes) )) # muon and 'other'
model.add(Activation("softmax")) # output probabilities

print(model.summary())

model.compile(
    loss="categorical_crossentropy",
    optimizer=keras.optimizers.adamax(lr=INIT_LEARNINGRATE),
    metrics=['accuracy'] 
    )


model.fit(
    x_train, y_train,
    batch_size = BATCH_SIZE,
    epochs = EPOCHS,
    validation_data = (x_val, y_val),
    shuffle = True
    )

#model.save_model("keras_basic_model.xgb")


# score

validation_predictions = model.predict_proba(val_part.loc[:, utils.SIMPLE_FEATURE_COLUMNS].values)[:, 1]
result = scoring.rejection90(val_part.label.values, validation_predictions, sample_weight=val_part.weight.values)
print(result)

# %%
# Defining a target function in which the parameter to be optimized is an input variable. This function will be treated as a
# black box and optimized
def target_function_1(LastSize, X_train=x_train, y_train=y_train, X_score=x_val, y_score=y_val):
    
    INIT_LEARNINGRATE = 5e-3
    BATCH_SIZE = 16  # should be a factor of len(x_train) and len(x_val) etc.
    EPOCHS = 3

    assert len(y_train) == len(x_train), "x_train and y_train not same length!"
    #assert len(y_train) % BATCH_SIZE == 0, "batch size should be multiple of training size,{0}/{1}".format(len(y_train),BATCH_SIZE)

    from keras.models import Sequential
    from keras.layers import Dense, Activation, Dropout
    from keras.layers.normalization import BatchNormalization

    K.clear_session()

    model = Sequential()
    model.add(Dense(100, activation='relu', input_shape=( len( utils.SIMPLE_FEATURE_COLUMNS ), ))) #length = input vars
    model.add(BatchNormalization())
    model.add(Dropout(0.1))
    model.add(Dense(LastSize , activation='relu'))
    model.add(Dense( len(classes) )) # muon and 'other'
    model.add(Activation("softmax")) # output probabilities

    model.compile(
        loss="categorical_crossentropy",
        optimizer=keras.optimizers.adamax(lr=INIT_LEARNINGRATE),
        metrics=['accuracy'] 
        )


    model.fit(
        x_train, y_train,
        batch_size = BATCH_SIZE,
        epochs = EPOCHS,
        validation_data = (x_val, y_val),
        shuffle = True
        )

    #model.save_model("keras_basic_model.xgb")


    # score

    validation_predictions = model.predict_proba(val_part.loc[:, utils.SIMPLE_FEATURE_COLUMNS].values)[:, 1]
    result = scoring.rejection90(val_part.label.values, validation_predictions, sample_weight=val_part.weight.values)
    print(result)
    
    return 1 - result

# %%
A = target_function_1(50,x_train, y_train,x_val,y_val)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 100)               6600
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 100)               400
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 50)                5050
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 102
# _________________________________________________________________
# activation_1 (Activation)    (None, 2)                 0
# =================================================================
# Total params: 12,152
# Trainable params: 11,952
# Non-trainable params: 200
# _________________________________________________________________
# None
# Train on 43565 samples, validate on 10892 samples
# Epoch 1/3
# 43565/43565 [==============================] - 8s 180us/step - loss: 0.2499 - acc: 0.9247 - val_loss: 0.2409 - val_acc: 0.9253
# Epoch 2/3
# 43565/43565 [==============================] - 7s 152us/step - loss: 0.2379 - acc: 0.9258 - val_loss: 0.2403 - val_acc: 0.9243
# Epoch 3/3
# 43565/43565 [==============================] - 8s 178us/step - loss: 0.2339 - acc: 0.9257 - val_loss: 0.2453 - val_acc: 0.9246
# 0.2905928374350971

# %%
# Setting dimensions for the parameter that is to be optimized
dimensions_1 = [
    (30, 70)
]

# %%
def plot_bo(bo, suggestion=None, value=None):
    a, b = bo.space.bounds[0]
    
    ### getting the latest model
    model = bo.models[-1]
    
    xs = np.linspace(a, b, num=100)
    x_model = bo.space.transform(xs.reshape(-1, 1).tolist())
    
    mean, std = model.predict(x_model, return_std=True)
    
    plt.subplots(nrows=1, ncols=2, figsize=(12, 4))
    
    plt.subplot(1, 2, 1)
    plt.scatter(
        np.array(bo.Xi)[:, 0],
        np.array(bo.yi),
        color='red',
        label='observations'
    )
    if suggestion is not None:
        plt.scatter([suggestion], value, color='blue', label='suggestion')
    
    plt.plot(xs, mean, color='green', label='model')
    plt.fill_between(xs, mean - 1.96 * std, mean + 1.96 * std, alpha=0.1, color='green')
    plt.legend()
    
    plt.subplot(1, 2, 2)
    acq = acq_func(x_model, model, np.min(bo.yi))
    plt.plot(xs, acq, label='Expected Improvement')
    plt.legend()
    
    plt.show()

# %%
### another utility function
def cum_min(xs):
    result = np.zeros_like(xs)
    cmin = xs[0]
    
    result[0] = xs[0]
    
    for i in range(1, xs.shape[0]):
        if cmin > xs[i]:
            cmin = xs[i]

        result[i] = cmin
    
    return result

# %%
from IPython import display

### plots progress of BO over time.

def plot_convergence(bo):
    display.clear_output(wait=True)
    values = np.array(bo.yi)
    
    plt.figure(figsize=(12, 6))
    plt.plot(cum_min(values), label='minimal discovered')
    plt.scatter(np.arange(len(bo.yi)), bo.yi, label='observations')
    plt.xlabel('step', fontsize=14)
    plt.ylabel('loss', fontsize=14)
    
    plt.legend(loc='upper right', fontsize=18)
    
    plt.show()

# %%
### create an instance of Baysian Optimizer
bo_gp_1 = Optimizer(
    ### telling optimizer boundaries for each parameter
    dimensions=dimensions_1,
    
    ### setting regressor
    base_estimator=GaussianProcessRegressor(
        kernel=RBF(length_scale_bounds=[1.0e-6, 1.0e+6]) + \
            WhiteKernel(noise_level=1.0e-5, noise_level_bounds=[1.0e-6, 1.0e-2]),
    ),
    n_initial_points=2,
    acq_func='EI',   
)

# %%
for i in range(20):
    x = bo_gp_1.ask()
    f = target_function_1(x[0], x_train, y_train, x_val, y_val)

    if len(bo_gp_1.models) > 0:
        plot_bo(bo_gp_1, suggestion=x, value=f)
    
    bo_gp_1.tell(x, f)
# Out:
# Train on 43565 samples, validate on 10892 samples
# Epoch 1/3
# 43565/43565 [==============================] - 8s 177us/step - loss: 0.2488 - acc: 0.9243 - val_loss: 0.2447 - val_acc: 0.9238
# Epoch 2/3
# 43565/43565 [==============================] - 6s 145us/step - loss: 0.2381 - acc: 0.9259 - val_loss: 0.2373 - val_acc: 0.9255
# Epoch 3/3
# 43565/43565 [==============================] - 6s 140us/step - loss: 0.2348 - acc: 0.9258 - val_loss: 0.2435 - val_acc: 0.9249
# 0.2925654610967114
# Train on 43565 samples, validate on 10892 samples
# Epoch 1/3
# 43565/43565 [==============================] - 7s 161us/step - loss: 0.2514 - acc: 0.9245 - val_loss: 0.2608 - val_acc: 0.9242
# Epoch 2/3
# 43565/43565 [==============================] - 6s 143us/step - loss: 0.2373 - acc: 0.9254 - val_loss: 0.2380 - val_acc: 0.9259
# Epoch 3/3
# 43565/43565 [==============================] - 7s 153us/step - loss: 0.2332 - acc: 0.9268 - val_loss: 0.2384 - val_acc: 0.9260
# 0.29842289736236743
# Train on 43565 samples, validate on 10892 samples
# Epoch 1/3
# 43565/43565 [==============================] - 8s 179us/step - loss: 0.2495 - acc: 0.9249 - val_loss: 0.2427 - val_acc: 0.9243
# Epoch 2/3
# 43565/43565 [==============================] - 8s 189us/step - loss: 0.2406 - acc: 0.9261 - val_loss: 0.2441 - val_acc: 0.9238
# Epoch 3/3
# 43565/43565 [==============================] - 7s 163us/step - loss: 0.2362 - acc: 0.9262 - val_loss: 0.2357 - val_acc: 0.9255
# 0.3035714654980934
# c:\miniconda\envs\py36\lib\site-packages\skopt\optimizer\optimizer.py:399: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Train on 43565 samples, validate on 10892 samples
# Epoch 1/3
# 43565/43565 [==============================] - 8s 177us/step - loss: 0.2520 - acc: 0.9252 - val_loss: 0.2543 - val_acc: 0.9243
# Epoch 2/3
# 43565/43565 [==============================] - 7s 156us/step - loss: 0.2394 - acc: 0.9260 - val_loss: 0.2548 - val_acc: 0.9238
# Epoch 3/3
# 43565/43565 [==============================] - 6s 145us/step - loss: 0.2353 - acc: 0.9257 - val_loss: 0.2450 - val_acc: 0.9232
# 0.33238644982966237
# c:\miniconda\envs\py36\lib\site-packages\skopt\optimizer\optimizer.py:399: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Train on 43565 samples, validate on 10892 samples
# Epoch 1/3
# 43565/43565 [==============================] - 8s 173us/step - loss: 0.2499 - acc: 0.9251 - val_loss: 0.2465 - val_acc: 0.9245
# Epoch 2/3
# 43565/43565 [==============================] - 7s 155us/step - loss: 0.2380 - acc: 0.9255 - val_loss: 0.2452 - val_acc: 0.9228
# Epoch 3/3
# 43565/43565 [==============================] - 6s 145us/step - loss: 0.2334 - acc: 0.9266 - val_loss: 0.2397 - val_acc: 0.9243
# 0.31014810313576713
# c:\miniconda\envs\py36\lib\site-packages\skopt\optimizer\optimizer.py:399: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Train on 43565 samples, validate on 10892 samples
# Epoch 1/3
# 43565/43565 [==============================] - 7s 164us/step - loss: 0.2508 - acc: 0.9246 - val_loss: 0.2474 - val_acc: 0.9253
# Epoch 2/3
# 43565/43565 [==============================] - 7s 150us/step - loss: 0.2376 - acc: 0.9259 - val_loss: 0.2471 - val_acc: 0.9241
# Epoch 3/3
# 43565/43565 [==============================] - 7s 166us/step - loss: 0.2341 - acc: 0.9254 - val_loss: 0.2403 - val_acc: 0.9240
# 0.3408239273248088
# c:\miniconda\envs\py36\lib\site-packages\skopt\optimizer\optimizer.py:399: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Train on 43565 samples, validate on 10892 samples
# Epoch 1/3
# 43565/43565 [==============================] - 7s 172us/step - loss: 0.2478 - acc: 0.9257 - val_loss: 0.2489 - val_acc: 0.9234
# Epoch 2/3
# 43565/43565 [==============================] - 8s 177us/step - loss: 0.2391 - acc: 0.9265 - val_loss: 0.2399 - val_acc: 0.9256
# Epoch 3/3
# 43565/43565 [==============================] - 7s 155us/step - loss: 0.2365 - acc: 0.9259 - val_loss: 0.2381 - val_acc: 0.9255
# 0.2922032131507057
# c:\miniconda\envs\py36\lib\site-packages\skopt\optimizer\optimizer.py:399: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Train on 43565 samples, validate on 10892 samples
# Epoch 1/3
# 43565/43565 [==============================] - 7s 170us/step - loss: 0.2503 - acc: 0.9247 - val_loss: 0.2524 - val_acc: 0.9243
# Epoch 2/3
# 43565/43565 [==============================] - 7s 160us/step - loss: 0.2386 - acc: 0.9255 - val_loss: 0.2469 - val_acc: 0.9248
# Epoch 3/3
# 43565/43565 [==============================] - 7s 152us/step - loss: 0.2346 - acc: 0.9254 - val_loss: 0.2471 - val_acc: 0.9249
# 0.31377636012915244
# c:\miniconda\envs\py36\lib\site-packages\skopt\optimizer\optimizer.py:399: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Train on 43565 samples, validate on 10892 samples
# Epoch 1/3
# 43565/43565 [==============================] - 7s 172us/step - loss: 0.2480 - acc: 0.9251 - val_loss: 0.2469 - val_acc: 0.9240
# Epoch 2/3
# 43565/43565 [==============================] - 7s 151us/step - loss: 0.2372 - acc: 0.9259 - val_loss: 0.2368 - val_acc: 0.9236
# Epoch 3/3
# 43565/43565 [==============================] - 6s 147us/step - loss: 0.2348 - acc: 0.9259 - val_loss: 0.2419 - val_acc: 0.9256
# 0.3214193502374833
# c:\miniconda\envs\py36\lib\site-packages\skopt\optimizer\optimizer.py:399: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Train on 43565 samples, validate on 10892 samples
# Epoch 1/3
# 43565/43565 [==============================] - 7s 165us/step - loss: 0.2498 - acc: 0.9251 - val_loss: 0.2432 - val_acc: 0.9249
# Epoch 2/3
# 43565/43565 [==============================] - 7s 154us/step - loss: 0.2397 - acc: 0.9259 - val_loss: 0.2371 - val_acc: 0.9248
# Epoch 3/3
# 43565/43565 [==============================] - 7s 157us/step - loss: 0.2337 - acc: 0.9256 - val_loss: 0.2420 - val_acc: 0.9257
# 0.2876172907673551
# c:\miniconda\envs\py36\lib\site-packages\skopt\optimizer\optimizer.py:399: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Train on 43565 samples, validate on 10892 samples
# Epoch 1/3
# 43565/43565 [==============================] - 7s 166us/step - loss: 0.2526 - acc: 0.9250 - val_loss: 0.2427 - val_acc: 0.9255
# Epoch 2/3
# 43565/43565 [==============================] - 7s 164us/step - loss: 0.2397 - acc: 0.9254 - val_loss: 0.2427 - val_acc: 0.9243
# Epoch 3/3
# 43565/43565 [==============================] - 8s 178us/step - loss: 0.2344 - acc: 0.9255 - val_loss: 0.2530 - val_acc: 0.9233
# 0.3207608326080879
# c:\miniconda\envs\py36\lib\site-packages\skopt\optimizer\optimizer.py:399: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Train on 43565 samples, validate on 10892 samples
# Epoch 1/3
# 43565/43565 [==============================] - 7s 165us/step - loss: 0.2491 - acc: 0.9246 - val_loss: 0.2466 - val_acc: 0.9236
# Epoch 2/3
# 43565/43565 [==============================] - 7s 158us/step - loss: 0.2394 - acc: 0.9256 - val_loss: 0.2380 - val_acc: 0.9248
# Epoch 3/3
# 43565/43565 [==============================] - 8s 180us/step - loss: 0.2340 - acc: 0.9257 - val_loss: 0.2430 - val_acc: 0.9234
# 0.35044675871811326
# c:\miniconda\envs\py36\lib\site-packages\skopt\optimizer\optimizer.py:399: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Train on 43565 samples, validate on 10892 samples
# Epoch 1/3
# 43565/43565 [==============================] - 8s 185us/step - loss: 0.2507 - acc: 0.9241 - val_loss: 0.2449 - val_acc: 0.9228
# Epoch 2/3
# 43565/43565 [==============================] - 8s 174us/step - loss: 0.2366 - acc: 0.9260 - val_loss: 0.2389 - val_acc: 0.9255
# Epoch 3/3
# 43565/43565 [==============================] - 8s 179us/step - loss: 0.2336 - acc: 0.9253 - val_loss: 0.2422 - val_acc: 0.9250
# 0.29552138375380044
# c:\miniconda\envs\py36\lib\site-packages\skopt\optimizer\optimizer.py:399: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Train on 43565 samples, validate on 10892 samples
# Epoch 1/3
# 43565/43565 [==============================] - 8s 179us/step - loss: 0.2512 - acc: 0.9245 - val_loss: 0.2469 - val_acc: 0.9224
# Epoch 2/3
# 43565/43565 [==============================] - 7s 155us/step - loss: 0.2367 - acc: 0.9260 - val_loss: 0.2515 - val_acc: 0.9226
# Epoch 3/3
# 43565/43565 [==============================] - 7s 150us/step - loss: 0.2342 - acc: 0.9255 - val_loss: 0.2362 - val_acc: 0.9249
# 0.3197232935935408
# c:\miniconda\envs\py36\lib\site-packages\skopt\optimizer\optimizer.py:399: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Train on 43565 samples, validate on 10892 samples
# Epoch 1/3
# 43565/43565 [==============================] - 8s 175us/step - loss: 0.2540 - acc: 0.9241 - val_loss: 0.2484 - val_acc: 0.9245
# Epoch 2/3
# 43565/43565 [==============================] - 7s 167us/step - loss: 0.2387 - acc: 0.9257 - val_loss: 0.2432 - val_acc: 0.9234
# Epoch 3/3
# 43565/43565 [==============================] - 6s 147us/step - loss: 0.2341 - acc: 0.9265 - val_loss: 0.2424 - val_acc: 0.9246
# 0.25587989632874525
# Train on 43565 samples, validate on 10892 samples
# Epoch 1/3
# 43565/43565 [==============================] - 7s 161us/step - loss: 0.2500 - acc: 0.9240 - val_loss: 0.2531 - val_acc: 0.9253
# Epoch 2/3
# 43565/43565 [==============================] - 7s 150us/step - loss: 0.2376 - acc: 0.9257 - val_loss: 0.2406 - val_acc: 0.9243
# Epoch 3/3
# 43565/43565 [==============================] - 7s 156us/step - loss: 0.2328 - acc: 0.9263 - val_loss: 0.2368 - val_acc: 0.9227
# 0.29967912031172406
# c:\miniconda\envs\py36\lib\site-packages\skopt\optimizer\optimizer.py:399: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Train on 43565 samples, validate on 10892 samples
# Epoch 1/3
# 43565/43565 [==============================] - 8s 185us/step - loss: 0.2487 - acc: 0.9248 - val_loss: 0.2400 - val_acc: 0.9255
# Epoch 2/3
# 43565/43565 [==============================] - 8s 172us/step - loss: 0.2378 - acc: 0.9257 - val_loss: 0.2379 - val_acc: 0.9251
# Epoch 3/3
# 43565/43565 [==============================] - 7s 150us/step - loss: 0.2334 - acc: 0.9262 - val_loss: 0.2383 - val_acc: 0.9260
# 0.3066030170014935
# c:\miniconda\envs\py36\lib\site-packages\skopt\optimizer\optimizer.py:399: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Train on 43565 samples, validate on 10892 samples
# Epoch 1/3
# 43565/43565 [==============================] - 8s 187us/step - loss: 0.2525 - acc: 0.9246 - val_loss: 0.2504 - val_acc: 0.9240
# Epoch 2/3
# 43565/43565 [==============================] - 7s 152us/step - loss: 0.2374 - acc: 0.9265 - val_loss: 0.2418 - val_acc: 0.9248
# Epoch 3/3
# 43565/43565 [==============================] - 7s 150us/step - loss: 0.2339 - acc: 0.9260 - val_loss: 0.2376 - val_acc: 0.9253
# 0.29170966594682585
# c:\miniconda\envs\py36\lib\site-packages\skopt\optimizer\optimizer.py:399: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Train on 43565 samples, validate on 10892 samples
# Epoch 1/3
# 43565/43565 [==============================] - 8s 175us/step - loss: 0.2493 - acc: 0.9254 - val_loss: 0.2444 - val_acc: 0.9248
# Epoch 2/3
# 43565/43565 [==============================] - 8s 173us/step - loss: 0.2398 - acc: 0.9262 - val_loss: 0.2467 - val_acc: 0.9248
# Epoch 3/3
# 43565/43565 [==============================] - 7s 167us/step - loss: 0.2359 - acc: 0.9259 - val_loss: 0.2434 - val_acc: 0.9257
# 0.3282597615371357
# c:\miniconda\envs\py36\lib\site-packages\skopt\optimizer\optimizer.py:399: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# Train on 43565 samples, validate on 10892 samples
# Epoch 1/3
# 43565/43565 [==============================] - 8s 179us/step - loss: 0.2497 - acc: 0.9252 - val_loss: 0.2402 - val_acc: 0.9244
# Epoch 2/3
# 43565/43565 [==============================] - 7s 160us/step - loss: 0.2383 - acc: 0.9260 - val_loss: 0.2482 - val_acc: 0.9233
# Epoch 3/3
# 43565/43565 [==============================] - 7s 164us/step - loss: 0.2352 - acc: 0.9257 - val_loss: 0.2387 - val_acc: 0.9253
# 0.2986036564635606
